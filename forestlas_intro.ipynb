# %%
# %load_ext autoreload
# %pylab
# %matplotlib inline
import os, glob
import pandas as pd
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path += ['forestlas']
from forestlas import lasIO
from forestlas import canopyComplexity as cc

# %%
os.chdir('/home/ucfaptv/lucas/Lidar_2018_Small_plots_Normalizado')

# %%
# reads .las file "WC1.las" including all point metadata in verbose mode
las = lasIO.lasIO('A-1.las', keepTemp=True)

# returns as an numpy array 
lasAll = las.all().asArray()

# plot histogram of height
plt.hist(lasAll['z'], int(lasAll['z'].max() / 2), orientation="horizontal")
plt.ylabel("height")
plt.xlabel("number of returns")
# Out:
# Text(0.5,0,'number of returns')

# %%
pgap.zxOrig[np.where(np.isclose(pgap.pgap, .2, atol=.05))][-1]
# Out:
# 2.19

# %%
# %autoreload 2
df = pd.DataFrame(columns=['name', 'zmax', 'pgap80', 'pgap60', 'pgap40', 'pgap20'])

for i, l in enumerate(glob.glob('*.las')):
    
    print 'processing:', l
    #try:
    las = lasIO.lasIO(l).all().asArray()
    las['z'] = las['z'] - las['z'].min()
    df.loc[i, 'name'] = l
    df.loc[i, 'zmax'] = las['z'].max()
    pgap = cc.CanopyComplexity().fromLAS(las).Pgap()
    for j, gap_prob in enumerate([.8, .6, .4, .2]):
        try:
            gpz = pgap.zxOrig[np.where(np.isclose(pgap.pgap, gap_prob, atol=.05))][-1]
        except:
            gpz = -1
        df.loc[i, ['pgap80', 'pgap60', 'pgap40', 'pgap20'][j]] = gpz
    

    #  print 'something went wrong'
# Out:
# processing: F-30.las
# self.bins: 2782
# processing: P-30.las
# self.bins: 2095
# processing: F-29.las
# self.bins: 2879
# processing: P-28.las
# self.bins: 2104
# processing: F-25.las
# self.bins: 2187
# processing: P-26.las
# self.bins: 2069
# processing: F-26.las
# self.bins: 3076
# processing: P-29.las
# self.bins: 3216
# processing: F-21.las
# self.bins: 3161
# processing: P-27.las
# self.bins: 3390
# processing: F-24.las
# self.bins: 2960
# processing: P-25.las
# self.bins: 2064
# processing: F-11.las
# self.bins: 3515
# processing: P-24.las
# self.bins: 2403
# processing: F-14.las
# self.bins: 1785
# processing: P-21.las
# self.bins: 2249
# processing: F-10.las
# self.bins: 3355
# processing: P-22.las
# self.bins: 3099
# processing: F-9.las
# self.bins: 3334
# processing: P-23.las
# self.bins: 2330
# processing: F-6.las
# self.bins: 3812
# processing: P-20.las
# self.bins: 3477
# processing: F-7.las
# self.bins: 3279
# processing: P-19.las
# self.bins: 2551
# ...
